# %% [markdown]
# # Indexing and slicing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df['starttime']
# Out:
# 0        2018-05-01 00:04:47
# 1        2018-05-01 01:31:10
# 2        2018-05-01 01:31:29
# 3        2018-05-01 02:03:29
# 4        2018-05-01 04:27:12
#                 ...
# 32423    2018-05-30 13:49:18
# 32424    2018-05-30 13:49:21
# 32425    2018-05-30 13:49:51
# 32426    2018-05-30 13:50:52
# 32427    2018-05-30 13:50:58
# Name: starttime, Length: 32428, dtype: object

# %%
df[['tripduration' , 'starttime' , 'stoptime']]
# Out:
#        tripduration            starttime             stoptime
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
# [32428 rows x 3 columns]

# %%
# Extract the to 10 bikeid's

df['bikeid'].head(10)
# Out:
# 0    33558
# 1    33593
# 2    29217
# 3    29662
# 4    15271
# 5    29298
# 6    33619
# 7    33624
# 8    26300
# 9    33555
# Name: bikeid, dtype: int64

# %%
df.head(10)['bikeid']
# Out:
# 0    33558
# 1    33593
# 2    29217
# 3    29662
# 4    15271
# 5    29298
# 6    33619
# 7    33624
# 8    26300
# 9    33555
# Name: bikeid, dtype: int64

# %% [markdown]
# # method 1

# %%
df['start station name'][1]
# Out:
# 'Grand St'

# %%
# Method 2

df.at[1, 'start station name']
# Out:
# 'Grand St'

# %%
df['tripduration'][3] = 200
# Out:
# C:\Users\Mohammed Israr\AppData\Local\Temp\ipykernel_10140\2702156654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tripduration'][3] = 200

# %%
df.at[2 , 'tripduration'] = 300

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # Slicing can be done by 3 methods
#
# 1. Normal method
#
# 2. loc
#
# 3. iloc

# %%
new_df = df.head(10)
e_list = []

for i in new_df.index:
    e_list.append(f'row_{i}')

new_df.index = e_list

new_df
# Out:
#        tripduration            starttime             stoptime  \
# row_0           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# row_6           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# row_7           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# row_8           395  2018-05-01 05:12:07  2018-05-01 05:18:42
# row_9           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#        start station id     start station name  end station id  \
# row_0              3639             Harborside            3199
# row_1              3681               Grand St            3185
# row_2              3194        McGinley Square            3193
# ...

# %% [markdown]
# # Normal slicing
#
# - slicing on columns is not allowed
#
# 1. zero indexing
# - start is inclusive
# - stop is exclusive
#
# 2. custom indexing
# - start is inclusive
# - stop is inclusive

# %%
new_df[2 : 5] # store it into df then print
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber

# %%
new_df[5 : 8]
# Out:
#        tripduration            starttime             stoptime  \
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# row_6           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# row_7           830  2018-05-01 05:11:50  2018-05-01 05:25:41
#
#        start station id     start station name  end station id  \
# row_5              3194        McGinley Square            3195
# row_6              3225  Baldwin at Montgomery            3186
# row_7              3207            Oakland Ave            3185
#
#       end station name  bikeid                   name_localizedValue  \
# row_5          Sip Ave   29298                     Annual Membership
# row_6    Grove St PATH   33619  Annual Membership from Citi Bike App
# row_7        City Hall   33624                     Annual Membership
#
#          usertype
# row_5  Subscriber
# row_6  Subscriber
# row_7  Subscriber

# %%
new_df['row_2' : 'row_5']
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
# row_5              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber
# ...

# %% [markdown]
# # loc method
#
# - slicing on rows and columns are allowed
#
# 1. custom indexing
# - start is inclusive
# - stop is inclusive

# %%
new_df.loc[2 : 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 new_df.loc[2 : 5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1373, in _LocIndexer._getitem_axis(self, key, axis)
#    1371 if isinstance(key, slice):
#    1372     self._validate_key(key, axis)
# -> 1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
#    1375     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1405, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1402     return obj.copy(deep=False)
# ...

# %%
new_df.loc['row_2' : 'row_5']
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
# row_5              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber
# ...

# %%
new_df.loc['row_2' : 'row_5' , 'start station id' : 'end station name']
# Out:
#        start station id start station name  end station id end station name
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
# row_5              3194    McGinley Square            3195          Sip Ave

# %%
new_df.loc['row_1' : 'row_3' :2 , 'starttime' : 'end station id' : 2]
# Out:
#                  starttime  start station id  end station id
# row_1  2018-05-01 01:31:10              3681            3185
# row_3  2018-05-01 02:03:29              3185            3186

# %%
df[2:4]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           200  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name  end station id end station name  bikeid  \
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
#
#                        name_localizedValue    usertype
# 2  FREE Bonus Month with Annual Membership  Subscriber
# 3                                  24 Hour    Customer

# %%
df.loc[2:4]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           200  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 2  FREE Bonus Month with Annual Membership  Subscriber
# 3                                  24 Hour    Customer
# 4                        Annual Membership  Subscriber

# %%
df.loc[10 : 30 : 10 , ::2]
# Out:
#     tripduration             stoptime     start station name end station name  \
# 10           353  2018-05-01 05:24:29  Baldwin at Montgomery          Sip Ave
# 20           261  2018-05-01 06:00:28        Jersey & 6th St     Newport PATH
# 30           452  2018-05-01 06:23:28            Astor Place          Sip Ave
#
#    name_localizedValue
# 10   Annual Membership
# 20   Annual Membership
# 30   Annual Membership

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # iloc method
#
# - slicing on rows and columns are allowed
#
# 1. zero indexing
# - start is inclusive
# - stop is exclusive

# %%
new_df.iloc['row_2' , 'row_4']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     939 try:
# --> 940     self._validate_key(k, i)
#     941 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1576, in _iLocIndexer._validate_key(self, key, axis)
#    1575 else:
# -> 1576     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 new_df.iloc['row_2' , 'row_4']
#
# ...

# %%
new_df.iloc[2:5]
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber

# %%
new_df.iloc[2:5 , 3:7]
# Out:
#        start station id start station name  end station id end station name
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32428, step=1)

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'end station id', 'end station name', 'bikeid',
#        'name_localizedValue', 'usertype'],
#       dtype='object')

# %%
dict(zip(range(len(df.columns)) , df.columns))
# Out:
# {0: 'tripduration',
#  1: 'starttime',
#  2: 'stoptime',
#  3: 'start station id',
#  4: 'start station name',
#  5: 'end station id',
#  6: 'end station name',
#  7: 'bikeid',
#  8: 'name_localizedValue',
#  9: 'usertype'}

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # Filtering the data

# %%
df['usertype'] == 'Customer'
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 32423    False
# 32424    False
# 32425    False
# 32426    False
# 32427    False
# Name: usertype, Length: 32428, dtype: bool

# %%
df[df['usertype'] == 'Customer']
# Out:
#        tripduration            starttime             stoptime  \
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 35              367  2018-05-01 06:28:03  2018-05-01 06:34:10
# 139             699  2018-05-01 07:45:27  2018-05-01 07:57:07
# 151             334  2018-05-01 07:52:39  2018-05-01 07:58:14
# ...             ...                  ...                  ...
# 32348           842  2018-05-30 12:15:18  2018-05-30 12:29:21
# 32352           278  2018-05-30 12:21:07  2018-05-30 12:25:46
# 32353          1004  2018-05-30 12:21:20  2018-05-30 12:38:04
# 32358           557  2018-05-30 12:28:48  2018-05-30 12:38:06
# 32391          4387  2018-05-30 13:12:04  2018-05-30 14:25:12
#
#        start station id start station name  end station id  end station name  \
# 1                  3681           Grand St            3185         City Hall
# ...

# %%
df[(df['usertype'] == 'Customer') & (df['tripduration'] >= 1000)]
# Out:
#        tripduration            starttime             stoptime  \
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 222            4929  2018-05-01 08:17:21  2018-05-01 09:39:31
# 408            3191  2018-05-01 10:05:07  2018-05-01 10:58:19
# 466            1840  2018-05-01 11:53:20  2018-05-01 12:24:01
# 467            1835  2018-05-01 11:53:36  2018-05-01 12:24:11
# ...             ...                  ...                  ...
# 32293          2230  2018-05-30 11:11:17  2018-05-30 11:48:28
# 32295          1896  2018-05-30 11:12:13  2018-05-30 11:43:50
# 32327          1135  2018-05-30 11:54:15  2018-05-30 12:13:11
# 32353          1004  2018-05-30 12:21:20  2018-05-30 12:38:04
# 32391          4387  2018-05-30 13:12:04  2018-05-30 14:25:12
#
#        start station id  start station name  end station id  \
# 1                  3681            Grand St            3185
# 222                3183      Exchange Place            3183
# ...

# %%
df[(condition1) & | (condition2)]

# %%
df[(df['usertype'] == 'Subscriber') & (df['start station name'] == 'Harborside')]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# 83              397  2018-05-01 07:10:27  2018-05-01 07:17:04
# 227             325  2018-05-01 08:19:11  2018-05-01 08:24:37
# 234             372  2018-05-01 08:22:21  2018-05-01 08:28:33
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
df[(df['usertype'] == 'Subscriber') & 
((df['start station name'] == 'Harborside') | (df['start station name'] == 'Grand St'))]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# 83              397  2018-05-01 07:10:27  2018-05-01 07:17:04
# 104             125  2018-05-01 07:23:51  2018-05-01 07:25:57
# 227             325  2018-05-01 08:19:11  2018-05-01 08:24:37
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
df.query('''
usertype == 'Subscriber' and `start station name` == 'Harborside'
''')
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# 83              397  2018-05-01 07:10:27  2018-05-01 07:17:04
# 227             325  2018-05-01 08:19:11  2018-05-01 08:24:37
# 234             372  2018-05-01 08:22:21  2018-05-01 08:28:33
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
df.query('''
usertype == 'Subscriber' and `start station name` in ('Harborside' , 'Grand St')
''')
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# 83              397  2018-05-01 07:10:27  2018-05-01 07:17:04
# 104             125  2018-05-01 07:23:51  2018-05-01 07:25:57
# 227             325  2018-05-01 08:19:11  2018-05-01 08:24:37
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
usertype == Subscriber

start station name --> Harborside or Grand St
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df.query(f'''
usertype == 'Subscriber' and `start station name` in {('Harborside' , 'Grand St')}
''')
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# 83              397  2018-05-01 07:10:27  2018-05-01 07:17:04
# 104             125  2018-05-01 07:23:51  2018-05-01 07:25:57
# 227             325  2018-05-01 08:19:11  2018-05-01 08:24:37
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
df[(df['name_localizedValue'] == 'Annual Membership') | (df['name_localizedValue'] == '24 Hour') | 
(df['name_localizedValue'] == '$25 Off Annual Membership')]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ...             ...                  ...                  ...
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df.query('''
name_localizedValue in ['Annual Membership', '24 Hour' , '$25 Off Annual Membership']
''')
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ...             ...                  ...                  ...
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
l = ['Annual Membership', '24 Hour' , '$25 Off Annual Membership']

df.query(f'''
name_localizedValue in {l}
''')
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ...             ...                  ...                  ...
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
usertype

# %%
df['usertype'].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
df[df['usertype'] == 'Subscriber']['tripduration'].max()
# Out:
# 608122

# %%
df[df['usertype'] == 'Customer']['tripduration'].max()
# Out:
# 936970

# %%
df[df['tripduration'] == df[df['usertype'] == 'Subscriber']['tripduration'].max()]
# Out:
#        tripduration            starttime             stoptime  \
# 11529        608122  2018-05-10 10:32:11  2018-05-17 11:27:34
#
#        start station id start station name  end station id end station name  \
# 11529              3426         JCBS Depot            3426       JCBS Depot
#
#        bikeid name_localizedValue    usertype
# 11529   29273   Motivate Employee  Subscriber

# %%
df[df['tripduration'] == df[df['usertype'] == 'Customer']['tripduration'].max()]
# Out:
#        tripduration            starttime             stoptime  \
# 10873        936970  2018-05-09 20:04:32  2018-05-20 16:20:42
#
#        start station id start station name  end station id  end station name  \
# 10873              3638      Washington St            3198  Heights Elevator
#
#        bikeid name_localizedValue  usertype
# 10873   26210             24 Hour  Customer

# %%
e = []

for i in df['usertype'].unique():
    m = df[df['usertype'] == i]['tripduration'].max()
    e.append(m)

e
# Out:
# [608122, 936970]

# %%
df.query(f'''
tripduration in {e}
''')
# Out:
#        tripduration            starttime             stoptime  \
# 10873        936970  2018-05-09 20:04:32  2018-05-20 16:20:42
# 11529        608122  2018-05-10 10:32:11  2018-05-17 11:27:34
#
#        start station id start station name  end station id  end station name  \
# 10873              3638      Washington St            3198  Heights Elevator
# 11529              3426         JCBS Depot            3426        JCBS Depot
#
#        bikeid name_localizedValue    usertype
# 10873   26210             24 Hour    Customer
# 11529   29273   Motivate Employee  Subscriber

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df['tripduration'].sort_values(ascending = False).index[0]
# Out:
# 10873

# %%
df.loc[10873]
# Out:
# tripduration                        936970
# starttime              2018-05-09 20:04:32
# stoptime               2018-05-20 16:20:42
# start station id                      3638
# start station name           Washington St
# end station id                        3198
# end station name          Heights Elevator
# bikeid                               26210
# name_localizedValue                24 Hour
# usertype                          Customer
# Name: 10873, dtype: object

# %%
df[df['start station name'] == 'Harborside']['tripduration'].sort_values(ascending = False).index[0]
# Out:
# 12132

# %%
df[df['start station name'] == 'Grand St']['tripduration'].sort_values(ascending = False).index[0]
# Out:
# 9019

# %%
l = [12132 , 9019]

df.loc[l]
# Out:
#        tripduration            starttime             stoptime  \
# 12132         44286  2018-05-10 19:47:19  2018-05-11 08:05:26
# 9019          49861  2018-05-08 16:33:41  2018-05-09 06:24:43
#
#        start station id start station name  end station id end station name  \
# 12132              3639         Harborside            3203    Hamilton Park
# 9019               3681           Grand St            3681         Grand St
#
#        bikeid name_localizedValue  usertype
# 12132   29681             24 Hour  Customer
# 9019    26151             24 Hour  Customer

# %%
l = []

for i in df['start station name'].unique():
    m = df[df['start station name'] == i]['tripduration'].sort_values(ascending = False).index[0]
    l.append(m)

df.loc[l]
# Out:
#        tripduration            starttime             stoptime  \
# 12132         44286  2018-05-10 19:47:19  2018-05-11 08:05:26
# 9019          49861  2018-05-08 16:33:41  2018-05-09 06:24:43
# 13153          5812  2018-05-11 17:43:45  2018-05-11 19:20:37
# 15254         55010  2018-05-14 15:48:17  2018-05-15 07:05:07
# 643            2581  2018-05-01 16:31:03  2018-05-01 17:14:05
# 23727         23911  2018-05-23 01:06:50  2018-05-23 07:45:22
# 27272         14470  2018-05-25 13:52:23  2018-05-25 17:53:34
# 6561          16102  2018-05-06 14:51:34  2018-05-06 19:19:57
# 27513         83360  2018-05-25 16:40:29  2018-05-26 15:49:50
# 5260          21106  2018-05-05 10:58:58  2018-05-05 16:50:44
# 6677          50584  2018-05-06 17:14:18  2018-05-07 07:17:23
# 24719        677711  2018-05-23 18:27:42  2018-05-31 14:42:53
# 29544        173196  2018-05-28 11:38:43  2018-05-30 11:45:20
# 30121          4684  2018-05-28 18:39:38  2018-05-28 19:57:42
# ...

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # Adding and deleting columns
